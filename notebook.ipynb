# %%
# %run -i main.py
# Out:
# (4032, 3024, 3)
# 24032703 out of 36578304 pixels are whitish
# 65.70207027641304% of the image is whitish
# 4032
# starting thread <Thread(Thread-4 (alter), initial)>
# starting thread <Thread(Thread-5 (alter), initial)>
# starting thread <Thread(Thread-6 (alter), initial)>
# starting thread <Thread(Thread-7 (alter), initial)>
# starting thread <Thread(Thread-8 (alter), initial)>
# starting thread <Thread(Thread-9 (alter), initial)>
# starting thread <Thread(Thread-10 (alter), initial)>
# starting thread <Thread(Thread-11 (alter), initial)>
# starting thread <Thread(Thread-12 (alter), initial)>
# starting thread <Thread(Thread-13 (alter), initial)>
# starting thread <Thread(Thread-14 (alter), initial)>
# starting thread <Thread(Thread-15 (alter), initial)>
# starting thread <Thread(Thread-16 (alter), initial)>
# starting thread <Thread(Thread-17 (alter), initial)>
# starting thread <Thread(Thread-18 (alter), initial)>
# starting thread <Thread(Thread-19 (alter), initial)>
